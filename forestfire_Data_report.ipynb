# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bankdata=pd.read_csv('forestfires.csv')

# %%
bankdata
cols = pd.MultiIndex.from_product([bankdata, ['mon', 'tue','wed','thu','fri','sat','sun']])
lala=pd.DataFrame(np.random.randn(1,91), columns=cols)
lala.T
# Out:
#                   0
# X     mon -1.270060
#       tue -0.517486
#       wed -0.878472
#       thu -1.666097
#       fri  0.066030
#       sat  0.792216
#       sun  1.931612
# Y     mon  0.361599
#       tue -1.066323
#       wed  1.337848
#       thu  0.929149
#       fri -1.205648
#       sat  0.150446
#       sun -0.142640
# month mon -1.384929
#       tue -1.001604
#       wed  0.078901
#       thu  0.422880
#       fri -0.045471
#       sat  1.183618
#       sun -0.042986
# day   mon -0.094922
#       tue  0.053268
#       wed -0.139930
#       thu -0.426812
#       fri -0.626551
#       sat  0.357950
#       sun -0.278537
# FFMC  mon -0.813909
#       tue  0.716327
# ...             ...
# temp  sat -0.562477
#       sun  1.196253
# RH    mon  1.368058
#       tue  0.345905
#       wed -3.056516
#       thu  0.441818
#       fri -0.052023
#       sat  0.558209
#       sun -0.798530
# wind  mon -0.244960
#       tue  1.530823
#       wed  2.163920
#       thu -0.226346
# ...

# %%
monthwise=(bankdata.groupby('month'))

# %%
monthwisedata=monthwise.mean()
monthwisedata
# Out:
#               X         Y       FFMC         DMC          DC        ISI  \
# month
# apr    5.777778  4.222222  85.788889   15.911111   48.555556   5.377778
# aug    4.483696  4.282609  92.336957  153.732609  641.077717  11.072283
# dec    4.555556  5.000000  84.966667   26.122222  351.244444   3.466667
# feb    5.150000  4.400000  82.905000    9.475000   54.670000   3.350000
# jan    3.000000  4.500000  50.400000    2.400000   90.350000   1.450000
# jul    5.218750  4.593750  91.328125  110.387500  450.603125   9.393750
# jun    6.294118  4.823529  89.429412   93.382353  297.705882  11.776471
# mar    4.722222  4.481481  89.444444   34.542593   75.942593   7.107407
# may    5.000000  4.000000  87.350000   26.700000   93.750000   4.600000
# nov    6.000000  3.000000  79.500000    3.000000  106.700000   1.100000
# oct    5.866667  4.333333  90.453333   41.420000  681.673333   7.146667
# sep    4.383721  4.116279  91.243023  120.922674  734.615698   8.577326
#
# ...

# %%
monthwisedata=monthwisedata.iloc[::-1]
monthwisedata
# Out:
# month        apr         aug         dec     feb    jan         jul  \
# area    8.891111   12.489076   13.330000   6.275   0.00   14.369687
# rain    0.000000    0.058696    0.000000   0.000   0.00    0.006250
# wind    4.666667    4.086413    7.644444   3.755   2.00    3.734375
# RH     46.888889   45.489130   38.444444  55.700  89.00   45.125000
# temp   12.044444   21.631522    4.522222   9.635   5.25   22.109375
# ISI     5.377778   11.072283    3.466667   3.350   1.45    9.393750
# DC     48.555556  641.077717  351.244444  54.670  90.35  450.603125
# DMC    15.911111  153.732609   26.122222   9.475   2.40  110.387500
# FFMC   85.788889   92.336957   84.966667  82.905  50.40   91.328125
# Y       4.222222    4.282609    5.000000   4.400   4.50    4.593750
# X       5.777778    4.483696    4.555556   5.150   3.00    5.218750
#
# month         jun        mar    may    nov         oct         sep
# area     5.841176   4.356667  19.24    0.0    6.638000   17.942616
# ...

# %%
bankdata.set_index(pd.Index(bankdata['day']), inplace=True)
bankdata
del bankdata['day']

# %%
df=pd.read_csv('forestfires.csv')
sales_report = pd.pivot_table(df, index=["month", "day"], values=["temp","wind","rain"],
                           aggfunc=[np.sum, np.mean,np.std], fill_value=0)
print (sales_report)
# Out:
#            sum                    mean                            std  \
#           rain   temp   wind      rain       temp      wind      rain
# month day
# apr   fri  0.0   16.7    3.1  0.000000  16.700000  3.100000  0.000000
#       mon  0.0   10.9    3.1  0.000000  10.900000  3.100000  0.000000
#       sat  0.0    9.3    4.5  0.000000   9.300000  4.500000  0.000000
#       sun  0.0   44.7   17.0  0.000000  14.900000  5.666667  0.000000
#       thu  0.0   11.6   11.6  0.000000   5.800000  5.800000  0.000000
#       wed  0.0   15.2    2.7  0.000000  15.200000  2.700000  0.000000
# aug   fri  1.4  446.0  100.1  0.066667  21.238095  4.766667  0.305505
#       mon  0.0  340.4   43.1  0.000000  22.693333  2.873333  0.000000
#       sat  0.0  594.6  125.0  0.000000  20.503448  4.310345  0.000000
#       sun  1.0  850.3  176.7  0.025000  21.257500  4.417500  0.158114
#       thu  0.0  556.6   91.1  0.000000  21.407692  3.503846  0.000000
# ...

# %%
new=(sales_report.groupby('month'))
newmean=new.mean()
new=new.std()
# f=plt.figure(figsize=(100,100))
axmean=newmean[['mean']].plot(kind='bar',title="ForestFire Annual Report (Mean)",figsize=(15,10),legend=True,fontsize=12)
ax=new[['std']].plot(kind='bar',title="ForestFire Annual Report(Standard Deviation)",figsize=(15,10),legend=True,fontsize=12)
ax.set_xlabel("Month",fontsize=12)
ax.set_ylabel("Data")
axmean.set_xlabel("Month",fontsize=12)
axmean.set_ylabel("Data")
plt.show()
new
plt.savefig("deepanshi.pdf")
